# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import requests
from flatten_json import flatten

# %% [markdown]
# # Creating Nodes Files From the Biomarker Data

# %% [markdown]
# First, create a dataframe from the edgelist and create a new column with the extracted biomarker ID

# %%
def get_id(s):
    index = s.find(":")
    return s[index+1:]

# %%
def get_new_id(s):
    index = s.find("-")
    return s[:index]

# %%
edges = pd.read_csv("OWLNETS_edgelist.txt", sep='\t')
edges['subject_id'] = edges['subject'].apply(get_id)
display(edges)
# Out:
#                    subject                      predicate              object  \
# 0       BIOMARKER:AN3902-1       indicated_by_presence_of     DBSNP:rs7785013
# 1       BIOMARKER:AN3902-1   determined_using_sample_from      UBERON:0000178
# 2       BIOMARKER:AN3902-1        has_BEST_classification        OBCI:0000008
# 3       BIOMARKER:AN3902-1   indicates_risk_of_developing           DOID:3905
# 4       BIOMARKER:AN3903-1       indicated_by_presence_of    DBSNP:rs73159014
# ...                    ...                            ...                 ...
# 546644  BIOMARKER:AM9674-1        has_BEST_classification        OBCI:0000008
# 546645  BIOMARKER:AM9674-1   indicates_risk_of_developing           DOID:1324
# 546646  BIOMARKER:AM9675-1       indicated_by_presence_of  DBSNP:rs1338696489
# 546647  BIOMARKER:AM9675-1        has_BEST_classification        OBCI:0000008
# 546648  BIOMARKER:AM9675-1   indicates_risk_of_developing           DOID:9253
#
#        subject_id
# 0        AN3902-1
# 1        AN3902-1
# 2        AN3902-1
# 3        AN3902-1
# 4        AN3903-1
# ...           ...
# 546644   AM9674-1
# 546645   AM9674-1
# 546646   AM9675-1
# 546647   AM9675-1
# 546648   AM9675-1
#
# [546649 rows x 4 columns]

# %% [markdown]
# We'll define a function to find our target entity labels using the Biomarker (subject) id. The get_label_api function will return the output from the "biomarker/detail" request.

# %%
def get_response_api(biomarker_id):
    response = requests.get(f'https://hivelab.biochemistry.gwu.edu/biomarker/api/biomarker/detail/{biomarker_id}', timeout=30)
    response = response.text[1:]
    return response

# %%
def get_label_biomarker(biomarker_id):
    ind = response.find("{") + 3
    response = response[ind:]
    ind = response.find(":") + 3
    response = response[ind:]
    backind = response.find(",")
    response = response[:backind-1]
    return response

# %% [markdown]
# Get a list of the different target node types. The fields we have to access in the response depend on these different types. We will also need to create a [node_type].nodes.csv file for each one.

# %%
def get_prefix(s):
    index = s.find(":")
    return s[:index]

# %%
def get_type(source):
    if source == "DBSNP":
        type = "Variant"
    elif source == "OBCI":
        type = "Role"
    elif source == "UBERON":
        type = "Anatomy"
    elif source == "DOID":
        type = "Condition"
    elif source == "PUBCHEM":
        type = "Compound"
    else: type = "Gene"
    return type

# %%
edges['object_type'] = edges['object'].apply(get_prefix)
edges['type'] = edges['object_type'].apply(get_type)
display(edges)
print((edges.object_type).unique())
print((edges.predicate).unique())
# Out:
#                    subject                      predicate              object  \
# 0       BIOMARKER:AN3902-1       indicated_by_presence_of     DBSNP:rs7785013
# 1       BIOMARKER:AN3902-1   determined_using_sample_from      UBERON:0000178
# 2       BIOMARKER:AN3902-1        has_BEST_classification        OBCI:0000008
# 3       BIOMARKER:AN3902-1   indicates_risk_of_developing           DOID:3905
# 4       BIOMARKER:AN3903-1       indicated_by_presence_of    DBSNP:rs73159014
# ...                    ...                            ...                 ...
# 546644  BIOMARKER:AM9674-1        has_BEST_classification        OBCI:0000008
# 546645  BIOMARKER:AM9674-1   indicates_risk_of_developing           DOID:1324
# 546646  BIOMARKER:AM9675-1       indicated_by_presence_of  DBSNP:rs1338696489
# 546647  BIOMARKER:AM9675-1        has_BEST_classification        OBCI:0000008
# 546648  BIOMARKER:AM9675-1   indicates_risk_of_developing           DOID:9253
#
#        subject_id object_type       type
# 0        AN3902-1       DBSNP    Variant
# 1        AN3902-1      UBERON    Anatomy
# 2        AN3902-1        OBCI       Role
# 3        AN3902-1        DOID  Condition
# 4        AN3903-1       DBSNP    Variant
# ...           ...         ...        ...
# 546644   AM9674-1        OBCI       Role
# 546645   AM9674-1        DOID  Condition
# 546646   AM9675-1       DBSNP    Variant
# 546647   AM9675-1        OBCI       Role
# 546648   AM9675-1        DOID  Condition
#
# [546649 rows x 6 columns]
# ['DBSNP' 'UBERON' 'OBCI' 'DOID' 'PUBCHEM' 'NCBI']
# ['indicated_by_presence_of' 'determined_using_sample_from'
#  'has_BEST_classification' ' indicates_risk_of_developing'
#  'indicated_by_above_normal_level_of' 'diagnostic_for'
#  'indicated_by_below_normal_level_of' 'prognostic_for']

# %% [markdown]
# We can create separate dataframes for each target node type to make things easier. In the end we will also make separate files for each edge type as well.

# %% [markdown]
# ## Extracting Node labels

# %% [markdown]
# We'll create a master dataframe that has each target entity node's "object_type", referring to it's source, and it's entity "type", which is the type of biological entity it is.

# %%
node_type = "PUBCHEM" # change this value to the source of the entity type you want to get the labels for
nodes = edges[edges["object_type"] == node_type]
nodes = nodes.drop_duplicates(subset=['object'])
nodes["object_id"] = nodes["object"].apply(get_id)
display(nodes)
# Out:
#                   subject                           predicate  \
# 17864  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17866  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17867  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17868  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17869  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17871  BIOMARKER:AN6165-1  indicated_by_above_normal_level_of
# 17875  BIOMARKER:AN6166-1  indicated_by_above_normal_level_of
# 17880  BIOMARKER:AN6167-1  indicated_by_above_normal_level_of
# 17882  BIOMARKER:AN6167-1  indicated_by_above_normal_level_of
# 17885  BIOMARKER:AN6167-1  indicated_by_above_normal_level_of
# 17887  BIOMARKER:AN6168-1  indicated_by_above_normal_level_of
# 17889  BIOMARKER:AN6168-1  indicated_by_above_normal_level_of
# 17890  BIOMARKER:AN6168-1  indicated_by_above_normal_level_of
# 17893  BIOMARKER:AN6169-1  indicated_by_above_normal_level_of
# 17896  BIOMARKER:AN6169-1  indicated_by_above_normal_level_of
# 17900  BIOMARKER:AN6170-1  indicated_by_above_normal_level_of
# 17904  BIOMARKER:AN6171-1  indicated_by_above_normal_level_of
# 17906  BIOMARKER:AN6171-1  indicated_by_above_normal_level_of
# 17909  BIOMARKER:AN6171-1  indicated_by_above_normal_level_of
# 17913  BIOMARKER:AN6172-1  indicated_by_above_normal_level_of
# 17915  BIOMARKER:AN6172-1  indicated_by_above_normal_level_of
# 17919  BIOMARKER:AN6173-1  indicated_by_above_normal_level_of
# 17921  BIOMARKER:AN6173-1  indicated_by_above_normal_level_of
# 17924  BIOMARKER:AN6174-1  indicated_by_above_normal_level_of
# 17928  BIOMARKER:AN6174-1  indicated_by_above_normal_level_of
# 17931  BIOMARKER:AN6175-1  indicated_by_above_normal_level_of
# 17933  BIOMARKER:AN6175-1  indicated_by_above_normal_level_of
# 17937  BIOMARKER:AN6176-1  indicated_by_above_normal_level_of
# 17939  BIOMARKER:AN6176-1  indicated_by_above_normal_level_of
# 17943  BIOMARKER:AN6177-1  indicated_by_above_normal_level_of
# 17945  BIOMARKER:AN6177-1  indicated_by_above_normal_level_of
# 17948  BIOMARKER:AN6178-1  indicated_by_above_normal_level_of
# 17952  BIOMARKER:AN6179-1  indicated_by_above_normal_level_of
# 17954  BIOMARKER:AN6179-1  indicated_by_above_normal_level_of
# 17957  BIOMARKER:AN6180-1  indicated_by_above_normal_level_of
# 17959  BIOMARKER:AN6180-1  indicated_by_below_normal_level_of
# 17965  BIOMARKER:AN6182-1  indicated_by_above_normal_level_of
# 17969  BIOMARKER:AN6183-1  indicated_by_above_normal_level_of
# 17973  BIOMARKER:AN6184-1  indicated_by_below_normal_level_of
# 17975  BIOMARKER:AN6184-1  indicated_by_above_normal_level_of
# 17978  BIOMARKER:AN6185-1  indicated_by_below_normal_level_of
# 17982  BIOMARKER:AN6186-1  indicated_by_below_normal_level_of
# 17986  BIOMARKER:AN6187-1  indicated_by_above_normal_level_of
#
#                   object subject_id object_type      type  object_id
# 17864       PUBCHEM:1662   AN6165-1     PUBCHEM  Compound       1662
# 17866      PUBCHEM:69362   AN6165-1     PUBCHEM  Compound      69362
# 17867    PUBCHEM:1551553   AN6165-1     PUBCHEM  Compound    1551553
# 17868      PUBCHEM:12284   AN6165-1     PUBCHEM  Compound      12284
# 17869   PUBCHEM:71464474   AN6165-1     PUBCHEM  Compound   71464474
# 17871   PUBCHEM:71296139   AN6165-1     PUBCHEM  Compound   71296139
# 17875     PUBCHEM:169485   AN6166-1     PUBCHEM  Compound     169485
# 17880     PUBCHEM:160471   AN6167-1     PUBCHEM  Compound     160471
# 17882   PUBCHEM:71464477   AN6167-1     PUBCHEM  Compound   71464477
# 17885    PUBCHEM:6441567   AN6167-1     PUBCHEM  Compound    6441567
# 17887     PUBCHEM:181976   AN6168-1     PUBCHEM  Compound     181976
# 17889        PUBCHEM:743   AN6168-1     PUBCHEM  Compound        743
# 17890   PUBCHEM:71317118   AN6168-1     PUBCHEM  Compound   71317118
# 17893     PUBCHEM:169235   AN6169-1     PUBCHEM  Compound     169235
# 17896     PUBCHEM:546304   AN6169-1     PUBCHEM  Compound     546304
# 17900        PUBCHEM:487   AN6170-1     PUBCHEM  Compound        487
# 17904     PUBCHEM:439681   AN6171-1     PUBCHEM  Compound     439681
# 17906      PUBCHEM:68152   AN6171-1     PUBCHEM  Compound      68152
# 17909     PUBCHEM:107738   AN6171-1     PUBCHEM  Compound     107738
# 17913    PUBCHEM:5459847   AN6172-1     PUBCHEM  Compound    5459847
# 17915    PUBCHEM:7045767   AN6172-1     PUBCHEM  Compound    7045767
# 17919   PUBCHEM:71464503   AN6173-1     PUBCHEM  Compound   71464503
# 17921  PUBCHEM:126456228   AN6173-1     PUBCHEM  Compound  126456228
# 17924      PUBCHEM:16950   AN6174-1     PUBCHEM  Compound      16950
# 17928       PUBCHEM:9750   AN6174-1     PUBCHEM  Compound       9750
# 17931        PUBCHEM:999   AN6175-1     PUBCHEM  Compound        999
# 17933       PUBCHEM:6140   AN6175-1     PUBCHEM  Compound       6140
# 17937      PUBCHEM:91552   AN6176-1     PUBCHEM  Compound      91552
# 17939       PUBCHEM:6137   AN6176-1     PUBCHEM  Compound       6137
# 17943      PUBCHEM:99288   AN6177-1     PUBCHEM  Compound      99288
# 17945    PUBCHEM:9886134   AN6177-1     PUBCHEM  Compound    9886134
# 17948       PUBCHEM:5312   AN6178-1     PUBCHEM  Compound       5312
# 17952       PUBCHEM:6238   AN6179-1     PUBCHEM  Compound       6238
# 17954      PUBCHEM:92827   AN6179-1     PUBCHEM  Compound      92827
# 17957  PUBCHEM:485716527   AN6180-1     PUBCHEM  Compound  485716527
# 17959       PUBCHEM:5819   AN6180-1     PUBCHEM  Compound       5819
# 17965        PUBCHEM:312   AN6182-1     PUBCHEM  Compound        312
# 17969       PUBCHEM:5793   AN6183-1     PUBCHEM  Compound       5793
# 17973        PUBCHEM:586   AN6184-1     PUBCHEM  Compound        586
# 17975        PUBCHEM:763   AN6184-1     PUBCHEM  Compound        763
# 17978  PUBCHEM:381121448   AN6185-1     PUBCHEM  Compound  381121448
# 17982  PUBCHEM:481101668   AN6186-1     PUBCHEM  Compound  481101668
# 17986  PUBCHEM:405235122   AN6187-1     PUBCHEM  Compound  405235122

# %% [markdown]
# Now we will go through the nodes dataframe and get the labels of each node using the biomarker id. Below are all of the different label-finding methods that differ depending on the  entity type.

# %%
def get_label_biomarker(biomarker_id):
    response = get_response_api(biomarker_id)
    ind = response.find("{") + 3
    response = response[ind:]
    ind = response.find(":") + 3
    response = response[ind:]
    backind = response.find(",")
    response = response[:backind-1]
    return response

# %%
def get_label_uberon(biomarker_id):
    response = get_response_api(biomarker_id)
    ind = response.find("specimen")
    response = response[ind:]
    ind = response.find("name")
    response = response[ind+len("name")+4:]
    ind = response.find(",")
    response = response[:ind-1]
    return response

# %%
def get_label_doid(biomarker_id, doid_id):
    response = get_response_api(biomarker_id)
    ind = response.find(doid_id)
    response = response[ind:]
    ind = response.find("id")
    response = response[ind+len("id"):]
    ind = response.find("name")
    response = response[ind+len("name")+4:]
    ind = response.find("description")
    response = response[:ind-4]
    return response

# %%
def get_label_dbsnp(biomarker_id):
    response = get_response_api(biomarker_id)
    ind = response.find("recommended_name")
    response = response[ind+len("recommended_name") + 4:]
    backind = response.find(",")
    response = response[:backind-1]
    print(biomarker_id, response)
    return response

# %%
def get_label_obci(biomarker_id):
    response = get_response_api(biomarker_id)
    ind = response.find("best_biomarker_role")
    response = response[ind+len("best_biomarker_role") + 4:]
    ind = response.find("role")
    response = response[ind+len("role") + 4:]
    backind = response.find("}")
    response = response[:backind-1]
    print(response)
    return response

# %%
def get_label_pubchem(biomarker_id, pubchem_id):
    response = get_response_api(biomarker_id)
    endInd = response.find(pubchem_id)
    response = response[:endInd]
    ind = response.rfind("name")
    response = response[ind:]
    response = response[len("name") + 4:]
    ind = response.find(",")
    response = response[:ind-1]
    return response

# %%
nodes['label'] = nodes.apply(lambda row: get_label_doid(row['subject_id'], row['object']), axis=1)
display(nodes)
# Out:
#               object subject_id                                          label
# 3          DOID:3905   AN3902-1                                 lung carcinoma
# 7          DOID:3192   AN3903-1                                   neurilemmoma
# 11         DOID:3910   AN3904-1                            lung adenocarcinoma
# 15         DOID:8552   AN3905-1                       chronic myeloid leukemia
# 18          DOID:162   AN3906-1                                         cancer
# ...              ...        ...                                            ...
# 337692     DOID:4927   AH2481-1                               Klatskin's tumor
# 353736  DOID:0060061   AH6520-1  primary cutaneous T-cell non-Hodgkin lymphoma
# 400203  DOID:0080916   AD6612-1                                erythroleukemia
# 407208  DOID:0080794   AD8463-1      childhood acute megakaryoblastic leukemia
# 449079     DOID:6262   AL8960-1              follicular dendritic cell sarcoma
#
# [370 rows x 3 columns]

# %% [markdown]
# We want to always name nodes files like so: "node_type.nodes.csv"

# %% [markdown]
# If you want to retrieve the labels for PubChem or DOID nodes, run this:

# %%
nodes['label'] = nodes.apply(lambda row: get_label_pubchem(row['subject_id'], row['object_id']), axis=1)
nodes = nodes.get(['object', 'label', 'type'])
nodes.to_csv("Compound.nodes.csv", index=False, sep=',')
display(nodes)
# Out:
#                   object                               label      type
# 17864       PUBCHEM:1662     3-hydroxy-3-methylglutaric acid  Compound
# 17866      PUBCHEM:69362           3-hydroxy-isovaleric acid  Compound
# 17867    PUBCHEM:1551553             3-methylglutaconic acid  Compound
# 17868      PUBCHEM:12284               3-methylglutaric acid  Compound
# 17869   PUBCHEM:71464474                 C5-OH acylcarnitine  Compound
# 17871   PUBCHEM:71296139                  C6DC acylcarnitine  Compound
# 17875     PUBCHEM:169485             3-Methylcrotonylglycine  Compound
# 17880     PUBCHEM:160471      2-methyl-3-hydroxybutyric acid  Compound
# 17882   PUBCHEM:71464477           3-hydroxybutyrylcarnitine  Compound
# 17885    PUBCHEM:6441567                       Tiglylglycine  Compound
# 17887     PUBCHEM:181976              3-hydroxyglutaric acid  Compound
# 17889        PUBCHEM:743                       Glutaric acid  Compound
# 17890   PUBCHEM:71317118           Glutaryl (C5DC) carnitine  Compound
# 17893     PUBCHEM:169235                 Isovalerylcarnitine  Compound
# 17896     PUBCHEM:546304                   Isovalerylglycine  Compound
# 17900        PUBCHEM:487                  Methylmalonic Acid  Compound
# 17904     PUBCHEM:439681                 2-Methylcitric acid  Compound
# 17906      PUBCHEM:68152                 3-OH Propionic acid  Compound
# 17909     PUBCHEM:107738             Propionylcarnitine (C3)  Compound
# 17913    PUBCHEM:5459847                 3-hydroxypropionate  Compound
# 17915    PUBCHEM:7045767                    C2 acylcarnitine  Compound
# 17919   PUBCHEM:71464503     Hydroxyacylcarnitine (C18:1-OH)  Compound
# 17921  PUBCHEM:126456228  Hydroxypalmitoylcarnitine (C16-OH)  Compound
# 17924      PUBCHEM:16950               Argininosuccinic acid  Compound
# 17928       PUBCHEM:9750                          Citrulline  Compound
# 17931        PUBCHEM:999                   Phenylacetic acid  Compound
# 17933       PUBCHEM:6140                       Phenylalanine  Compound
# 17937      PUBCHEM:91552                        Homocysteine  Compound
# 17939       PUBCHEM:6137                          Methionine  Compound
# 17943      PUBCHEM:99288                      Alloisoleucine  Compound
# 17945    PUBCHEM:9886134          Branched chain amino acids  Compound
# 17948       PUBCHEM:5312                     Succinylacetone  Compound
# 17952       PUBCHEM:6238              17-Hydroxyprogesterone  Compound
# 17954      PUBCHEM:92827                    21-Deoxycortisol  Compound
# 17957  PUBCHEM:485716527         Thyroid stimulating hormone  Compound
# 17959       PUBCHEM:5819                   Thyroxine hormone  Compound
# 17965        PUBCHEM:312                      Sweat chloride  Compound
# 17969       PUBCHEM:5793                                Glc4  Compound
# 17973        PUBCHEM:586                            Creatine  Compound
# 17975        PUBCHEM:763                Guanidinoacetic acid  Compound
# 17978  PUBCHEM:381121448                 Alpha-L-iduronidase  Compound
# 17982  PUBCHEM:481101668               Iduronate-2-sulfatase  Compound
# 17986  PUBCHEM:405235122         Very long chain fatty acids  Compound

# %% [markdown]
# If you want to get biomarker labels, run this:

# %%
nodes['label'] = nodes['subject_id'].apply(get_label_biomarker)
nodes = nodes.get(['subject', 'label', 'type'])
# collapses the nodes getting rid of the suffix
nodes['subject'] = nodes['subject'].apply(get_new_id)
nodes = nodes.drop_duplicates()
nodes.to_csv("Biomarker.nodes.csv", index=False, sep=',')
display(nodes)

# %% [markdown]
# Otherwise, run this:

# %%
nodes['label'] = nodes['subject_id'].apply(get_label_dbsnp)
nodes = nodes.get(['object', 'label', 'type'])
nodes.to_csv("Variant.nodes.csv", index=False, sep=',')
display(nodes)

# %% [markdown]
# ## Creating Edge Files

# %% [markdown]
# All of the edge files have a "subject" of a node from BIOMARKER, a relation, and a "object" of a node from another resource. We will separate edges by the resource of the object.

# %%
edges = pd.read_csv("OWLNETS_edgelist.txt", sep='\t')
edges['resource'] = edges['object'].apply(get_prefix)
edges['type'] = edges['resource'].apply(get_type)
display(edges)
# Out:
#                    subject                      predicate              object  \
# 0       BIOMARKER:AN3902-1       indicated_by_presence_of     DBSNP:rs7785013
# 1       BIOMARKER:AN3902-1   determined_using_sample_from      UBERON:0000178
# 2       BIOMARKER:AN3902-1        has_BEST_classification        OBCI:0000008
# 3       BIOMARKER:AN3902-1   indicates_risk_of_developing           DOID:3905
# 4       BIOMARKER:AN3903-1       indicated_by_presence_of    DBSNP:rs73159014
# ...                    ...                            ...                 ...
# 546644  BIOMARKER:AM9674-1        has_BEST_classification        OBCI:0000008
# 546645  BIOMARKER:AM9674-1   indicates_risk_of_developing           DOID:1324
# 546646  BIOMARKER:AM9675-1       indicated_by_presence_of  DBSNP:rs1338696489
# 546647  BIOMARKER:AM9675-1        has_BEST_classification        OBCI:0000008
# 546648  BIOMARKER:AM9675-1   indicates_risk_of_developing           DOID:9253
#
#        resource       type
# 0         DBSNP    Variant
# 1        UBERON    Anatomy
# 2          OBCI       Role
# 3          DOID  Condition
# 4         DBSNP    Variant
# ...         ...        ...
# 546644     OBCI       Role
# 546645     DOID  Condition
# 546646    DBSNP    Variant
# 546647     OBCI       Role
# 546648     DOID  Condition
#
# [546649 rows x 5 columns]

# %% [markdown]
# We will have edge files that look like "Biomarker.{relation}_{object node type}.{object node type}.edges.csv"

# %%
list_types = ((edges.type).unique())
print(list_types)
# Out:
# ['Variant' 'Anatomy' 'Role' 'Condition' 'Compound' 'Gene']

# %% [markdown]
# First separate edges by resource name.

# %%
dbsnp = edges[edges["resource"] == "DBSNP"]
uberon = edges[edges["resource"] == "UBERON"]
obci = edges[edges["resource"] == "OBCI"]
doid = edges[edges["resource"] == "DOID"]
pubchem = edges[edges["resource"] == "PUBCHEM"]
print(len(dbsnp) + len(uberon) + len(obci) + len(doid) + len(pubchem))
# Out:
# 546648

# %% [markdown]
# (Optional) Creating a table of edges per node type to summarize data

# %%
table = pd.DataFrame(columns = ["node type", "edges"])
table = pd.concat([pd.DataFrame([["Variant", len(dbsnp.index)]], columns=table.columns), table], ignore_index=True)
table = pd.concat([pd.DataFrame([["Anatomy", len(uberon.index)]], columns=table.columns), table], ignore_index=True)
table = pd.concat([pd.DataFrame([["Role", len(obci.index)]], columns=table.columns), table], ignore_index=True)
table = pd.concat([pd.DataFrame([["Condition", len(doid.index)]], columns=table.columns), table], ignore_index=True)
table = pd.concat([pd.DataFrame([["Compound", len(pubchem.index)]], columns=table.columns), table], ignore_index=True)
table.to_csv("edge_counts.csv", index=False, sep=",")

# %% [markdown]
# For each target entity type, we want to create files containing the edges between biomarkers and those entities. Some target entity types have multiple different relations with biomarkers (ex. prognostic for, diagnostic for), so we have to create multiple dataframes for each individual relation type.

# %%
doid = doid.get(["subject", "predicate", "object"])
doid['subject'] = doid['subject'].apply(get_new_id)

# gets rid of the space in front of "indicates", can delete this line
doid1 = doid[doid['predicate'] == ' indicates_risk_of_developing']
doid1['predicate'] ='indicates_risk_of_developing'
doid2 = doid[doid['predicate'] == 'prognostic_for']
doid3 = doid[doid['predicate'] == 'diagnostic_for']

display(doid1)
display(doid2)
display(doid3)

# Name the edge files in the format "Biomarker.relation.target_type.edges.csv".
doid1.to_csv("all_csv/Condition/Biomarker.indicates_risk_of_developing.Condition.edges.csv", index=False, sep=',')
doid2.to_csv("all_csv/Condition/Biomarker.prognostic_for.Condition.edges.csv", index=False, sep=',')
doid3.to_csv("all_csv/Condition/Biomarker.diagnostic_for.Condition.edges.csv", index=False, sep=',')
# Out:
#                  subject                      predicate     object
# 3       BIOMARKER:AN3902   indicates_risk_of_developing  DOID:3905
# 7       BIOMARKER:AN3903   indicates_risk_of_developing  DOID:3192
# 11      BIOMARKER:AN3904   indicates_risk_of_developing  DOID:3910
# 15      BIOMARKER:AN3905   indicates_risk_of_developing  DOID:8552
# 18      BIOMARKER:AN3906   indicates_risk_of_developing   DOID:162
# ...                  ...                            ...        ...
# 546636  BIOMARKER:AM9671   indicates_risk_of_developing   DOID:999
# 546639  BIOMARKER:AM9672   indicates_risk_of_developing   DOID:999
# 546642  BIOMARKER:AM9673   indicates_risk_of_developing  DOID:3672
# 546645  BIOMARKER:AM9674   indicates_risk_of_developing  DOID:1324
# 546648  BIOMARKER:AM9675   indicates_risk_of_developing  DOID:9253
#
# [181856 rows x 3 columns]
# /var/folders/xb/bmqyy0q9303b04mkwvb2k48m0000gn/T/ipykernel_14713/950900081.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doid1['predicate'] ='indicates_risk_of_developing'
#                  subject                     predicate     object
# 3       BIOMARKER:AN3902  indicates_risk_of_developing  DOID:3905
# 7       BIOMARKER:AN3903  indicates_risk_of_developing  DOID:3192
# 11      BIOMARKER:AN3904  indicates_risk_of_developing  DOID:3910
# 15      BIOMARKER:AN3905  indicates_risk_of_developing  DOID:8552
# 18      BIOMARKER:AN3906  indicates_risk_of_developing   DOID:162
# ...                  ...                           ...        ...
# 546636  BIOMARKER:AM9671  indicates_risk_of_developing   DOID:999
# 546639  BIOMARKER:AM9672  indicates_risk_of_developing   DOID:999
# 546642  BIOMARKER:AM9673  indicates_risk_of_developing  DOID:3672
# 546645  BIOMARKER:AM9674  indicates_risk_of_developing  DOID:1324
# 546648  BIOMARKER:AM9675  indicates_risk_of_developing  DOID:9253
#
# [180961 rows x 3 columns]
#                 subject       predicate        object
# 17991  BIOMARKER:AN4559  prognostic_for     DOID:1612
# 17999  BIOMARKER:AN4561  prognostic_for     DOID:1612
# 18007  BIOMARKER:AN4565  prognostic_for     DOID:2394
# 18117  BIOMARKER:AN4610  prognostic_for  DOID:0080650
# 18151  BIOMARKER:AN4624  prognostic_for  DOID:0080650
# ...                 ...             ...           ...
# 22897  BIOMARKER:AN6151  prognostic_for     DOID:9119
# 22900  BIOMARKER:AN6152  prognostic_for     DOID:9119
# 22906  BIOMARKER:AN6154  prognostic_for     DOID:3908
# 22926  BIOMARKER:AN6163  prognostic_for  DOID:0081252
# 22931  BIOMARKER:AN6164  prognostic_for  DOID:0081252
#
# [357 rows x 3 columns]
#                 subject       predicate        object
# 17879  BIOMARKER:AN6166  diagnostic_for  DOID:0050710
# 17899  BIOMARKER:AN6169  diagnostic_for    DOID:14753
# 17918  BIOMARKER:AN6172  diagnostic_for    DOID:14701
# 17923  BIOMARKER:AN6173  diagnostic_for  DOID:0080155
# 17930  BIOMARKER:AN6174  diagnostic_for    DOID:14755
# ...                 ...             ...           ...
# 22918  BIOMARKER:AN6159  diagnostic_for  DOID:0081252
# 22920  BIOMARKER:AN6160  diagnostic_for  DOID:0081252
# 22922  BIOMARKER:AN6161  diagnostic_for  DOID:0081252
# 22924  BIOMARKER:AN6162  diagnostic_for  DOID:0081252
# 22930  BIOMARKER:AN6164  diagnostic_for  DOID:0081252
#
# [538 rows x 3 columns]
